# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
plt.plot([1,2,3],[2,5,7])
plt.show()

# %%
plt.plot([1,2,3],[2,5,7])
plt.title("Abstract Graph")
plt.xlabel("This is X")
plt.ylabel("This is Y")
plt.show()

# %%
from matplotlib import style

# %%
x1 = [2,5,7]

# %%
y1 = [5,10,12]

# %%
x2 = [1,7,13]

# %%
y2 = [3,9,10]

# %%
style.use('ggplot')

# %%
plt.plot(x1,y1, label = "line 1", linewidth = 2)
plt.plot(x2,y2, label = "line 2")
plt.legend()
plt.show()

# %%
plt.scatter(x1,y1)
plt.show()
